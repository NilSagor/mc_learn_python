# %% [markdown]
# <a href="https://colab.research.google.com/github/NilSagor/mc_learn_python/blob/master/avocado_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
